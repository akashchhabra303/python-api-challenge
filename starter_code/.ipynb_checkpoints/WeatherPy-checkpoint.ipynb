# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

print (weather_api_key)
# Out:
# 3deb82a390883e56a802d2bd5b4f4a48

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
# why is is lat_lng in lat_lngS?
for lat_lng in lat_lngs:
    
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
print(cities)
# Out:
# ['vaini', 'liliani', 'ushuaia', 'sao filipe', 'port antonio', 'hermanus', 'parana', 'naestved', 'busselton', 'natal', 'tyrma', 'omboue', 'punta arenas', 'turayf', 'kapoeta', 'san patricio', 'kruisfontein', 'solovetskiy', 'dikson', 'hobart', 'moroni', 'saskylakh', 'jumla', 'evensk', 'upernavik', 'belmonte', 'larreynaga', 'albany', 'rikitea', 'vondrozo', 'bethel', 'bluff', 'port alfred', 'husavik', 'severodvinsk', 'san pedro buenavista', 'hobyo', 'barrow', 'lompoc', 'barentsburg', 'tabiauea', 'esperance', 'mar del plata', 'port hardy', 'pangai', 'chilliwack', 'isangel', 'port elizabeth', 'carnarvon', 'tuktoyaktuk', 'kapaa', 'tilichiki', 'narsaq', 'kita', 'conakry', 'tevaitoa', 'cape town', 'birao', 'san andres', 'cockburn town', 'souillac', 'yerbogachen', 'buala', 'kaitangata', 'broken hill', 'torbay', 'caravelas', 'cabo san lucas', 'castro', 'sobolevo', 'butaritari', 'chuy', 'haimen', 'buin', 'bredasdorp', 'vostok', 'taolanaro', 'dolgoye', 'anamur', 'jamestown', 'dubbo', 'yellowknife', 'georgetown', 'serra branca', 'samusu', 'korla', 'hesperia', 'sentyabrskiy', 'viedma', 'avarua', 'norman wells', 'hibbing', 'palmer', 'clyde river', 'keti bandar', 'djibo', 'bambous virieux', 'dudinka', 'amderma', 'illoqqortoormiut', 'saint-philippe', 'cidreira', 'quatre cocos', 'mahibadhoo', 'pisco', 'ilulissat', 'arraial do cabo', 'severo-kurilsk', 'oranjemund', 'hithadhoo', 'tadine', 'lebu', 'attawapiskat', 'tasiilaq', 'bow island', 'puerto ayora', 'guerrero negro', 'coquimbo', 'nizhneyansk', 'san miguel', 'vaitupu', 'kattivakkam', 'sabla', 'rosarito', 'srednekolymsk', 'cascais', 'tulsipur', 'thabazimbi', 'garissa', 'magdagachi', 'kayfan', 'rolim de moura', 'chokurdakh', 'teguldet', 'kupang', 'lagoa', 'zaterechnyy', 'rocha', 'gat', 'nikolskoye', 'saldanha', 'chima', 'byron bay', 'victoria', 'mataura', 'lasa', 'shaowu', 'poum', 'sitka', 'atuona', 'visby', 'yaan', 'colares', 'ishigaki', 'bandarbeyla', 'votkinsk', 'tura', 'bay roberts', 'karasburg', 'bonthe', 'alofi', 'qaanaaq', 'plettenberg bay', 'port hedland', 'ransang', 'bilibino', 'gewane', 'hilo', 'ajaccio', 'port blair', 'new norfolk', 'stephenville', 'inderborskiy', 'brigantine', 'champerico', 'port macquarie', 'verkhnyaya inta', 'asyut', 'charters towers', 'cherskiy', 'warrington', 'beloha', 'mys shmidta', 'baffa', 'manggar', 'sept-iles', 'isla vista', 'kodiak', 'kavieng', 'pemangkat', 'margate', 'hihifo', 'emba', 'pamanukan', 'azuaga', 'okha', 'qandahar', 'ostrovnoy', 'sabha', 'yar-sale', 'hella', 'yialos', 'placido de castro', 'atar', 'dona ines', 'batesville', 'longyearbyen', 'nemuro', 'mehriz', 'ancud', 'aporawan', 'saleaula', 'kaduna', 'duz', 'upata', 'mount gambier', 'bengkulu', 'puerto baquerizo moreno', 'lleida', 'yorosso', 'maldonado', 'manjacaze', 'provideniya', 'maragogi', 'tsihombe', 'belaya gora', 'shasta lake', 'petropavlovka', 'makakilo city', 'tlacotepec', 'amalapuram', 'irbeyskoye', 'rungata', 'louisbourg', 'sibolga', 'umzimvubu', 'portland', 'qasigiannguit', 'richards bay', 'todos santos', 'sambava', 'vao', 'nanortalik', 'kingsport', 'khatanga', 'cap malheureux', 'bathsheba', 'ponta delgada', 'denpasar', 'sisimiut', 'cody', 'ozgon', 'kailua', 'luanda', 'olafsvik', 'matara', 'ixtapa', 'sistranda', 'talnakh', 'gazni', 'cocentaina', 'honningsvag', 'puerto quijarro', 'sainte-suzanne', 'kaeo', 'udachnyy', 'abrau-dyurso', 'malwan', 'tiksi', 'brewster', 'coihaique', 'hamilton', 'kamenskoye', 'aflao', 'hienghene', 'leirvik', 'viligili', 'belushya guba', 'ontario', 'leningradskiy', 'bafra', 'pechenga', 'shumskiy', 'eureka', 'tumannyy', 'pirgos', 'east london', 'aquiraz', 'vestmannaeyjar', 'nome', 'vanimo', 'dzhusaly', 'caborca', 'luderitz', 'ghanzi', 'fare', 'nioro', 'itoman', 'kudahuvadhoo', 'nanpara', 'jamame', 'yima', 'pangnirtung', 'san cristobal', 'kahului', 'tungkang', 'ponta do sol', 'pedernales', 'fomboni', 'kushima', 'valparaiso', 'eregli', 'aracati', 'naze', 'benguela', 'kieta', 'doha', 'bonavista', 'santiago del estero', 'san juan', 'jeremie', 'ibra', 'iqaluit', 'ball ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
lst=[] 

record = 1
print(f"Beginning Data Retrieval")
print(f"-------------------------------")
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
record=1
for city in cities:
    
    
    
        
    #print(city)
#     print(response)
#     print(response["coord"]["lat"])
    try:
        response = requests.get(url + "&q=" + city).json()
    #     print (response)
        temp= response["main"]["temp"]
        lat= response["coord"]["lat"]
        lon= response["coord"]["lon"]
    #        print(lat)
    #         print(lon)
        city_name= response["name"]
    #         print(city_name)
        cloudiness=response["clouds"]["all"]
    #         print(cloudiness)
        wind_speed=response["wind"]["speed"]
    #         print(wind_speed)

        humidity=response["main"]["humidity"]
        date=response["dt"]
        country=response["sys"]["country"]
        print(country)

        #print(city_name)

        print(f"Processing Record {record} | {city_name}")
        record=record+1
        lst.append({
            'lat' : lat,
            'temp' : temp,
            'city_name' : city_name,
            'cloudiness' : cloudiness,
            'wind_speed' : wind_speed,
            'humidity' : humidity,
            'date' : date,
            'country' : country
        })
    
    except:
        print("City not found. Skipping...")
print("Complete")
        
print("size of list")
print(len(lst))
#         country=response["sys"]["country"]
#         max_temp.append(response["main"]["temp_max"])
#         lat.append(response["coord"]["lat"])
#         lng.append(response["coord"]["lon"])
#         city_record = response["name"]
#         print(f"Processing Record {record} | {city_record}")
#         print(f"{url}&q={city}")
#         record= record + 1
#         time.sleep(1.50)
# Out:
# Beginning Data Retrieval
# -------------------------------
# TO
# Processing Record 1 | Vaini
# PK
# Processing Record 2 | Liliani
# AR
# Processing Record 3 | Ushuaia
# CV
# Processing Record 4 | Sao Filipe
# JM
# Processing Record 5 | Port Antonio
# ZA
# Processing Record 6 | Hermanus
# AR
# Processing Record 7 | Parana
# DK
# Processing Record 8 | Naestved
# AU
# Processing Record 9 | Busselton
# BR
# Processing Record 10 | Natal
# RU
# Processing Record 11 | Tyrma
# GA
# Processing Record 12 | Omboue
# CL
# Processing Record 13 | Punta Arenas
# SA
# Processing Record 14 | Turaif
# SS
# Processing Record 15 | Kapoeta
# MX
# Processing Record 16 | San Patricio
# ZA
# Processing Record 17 | Kruisfontein
# City not found. Skipping...
# RU
# Processing Record 18 | Dikson
# AU
# Processing Record 19 | Hobart
# KM
# Processing Record 20 | Moroni
# RU
# Processing Record 21 | Saskylakh
# NP
# Processing Record 22 | Jumla
# RU
# Processing Record 23 | Evensk
# GL
# Processing Record 24 | Upernavik
# BR
# Processing Record 25 | Belmonte
# NI
# Processing Record 26 | Larreynaga
# US
# Processing Record 27 | Albany
# PF
# Processing Record 28 | Rikitea
# MG
# Processing Record 29 | Vondrozo
# US
# Processing Record 30 | Bethel
# NZ
# Processing Record 31 | Bluff
# ZA
# Processing Record 32 | Port Alfred
# IS
# Processing Record 33 | Husavik
# RU
# Processing Record 34 | Severodvinsk
# MX
# Processing Record 35 | San Pedro Buenavista
# SO
# Processing Record 36 | Hobyo
# US
# Processing Record 37 | Barrow
# US
# Processing Record 38 | Lompoc
# City not found. Skipping...
# City not found. Skipping...
# AU
# Processing Record 39 | Esperance
# AR
# Processing Record 40 | Mar del Plata
# CA
# Processing Record 41 | Port Hardy
# TO
# Processing Record 42 | Pangai
# CA
# Processing Record 43 | Chilliwack
# VU
# Processing Record 44 | Isangel
# ZA
# Processing Record 45 | Port Elizabeth
# AU
# Processing Record 46 | Carnarvon
# CA
# Processing Record 47 | Tuktoyaktuk
# US
# Processing Record 48 | Kapaa
# RU
# Processing Record 49 | Tilichiki
# GL
# Processing Record 50 | Narsaq
# ML
# Processing Record 51 | Kita
# GN
# Processing Record 52 | Conakry
# PF
# Processing Record 53 | Tevaitoa
# ZA
# Processing Record 54 | Cape Town
# CF
# Processing Record 55 | Birao
# CO
# Processing Record 56 | San Andres
# TC
# Processing Record 57 | Cockburn Town
# MU
# Processing Record 58 | Souillac
# RU
# Processing Record 59 | Yerbogachen
# SB
# Processing Record 60 | Buala
# NZ
# Processing Record 61 | Kaitangata
# AU
# Processing Record 62 | Broken Hill
# CA
# Processing Record 63 | Torbay
# BR
# Processing Record 64 | Caravelas
# MX
# Processing Record 65 | Cabo San Lucas
# BR
# Processing Record 66 | Castro
# RU
# Processing Record 67 | Sobolevo
# KI
# Processing Record 68 | Butaritari
# UY
# Processing Record 69 | Chui
# CN
# Processing Record 70 | Haimen
# CL
# Processing Record 71 | Buin
# ZA
# Processing Record 72 | Bredasdorp
# RU
# Processing Record 73 | Vostok
# City not found. Skipping...
# RU
# Processing Record 74 | Dolgoye
# TR
# Processing Record 75 | Anamur
# US
# Processing Record 76 | Jamestown
# AU
# Processing Record 77 | Dubbo
# CA
# Processing Record 78 | Yellowknife
# MY
# Processing Record 79 | George Town
# BR
# Processing Record 80 | Serra Branca
# City not found. Skipping...
# CN
# Processing Record 81 | Korla
# US
# Processing Record 82 | Hesperia
# City not found. Skipping...
# AR
# Processing Record 83 | Viedma
# CK
# Processing Record 84 | Avarua
# CA
# Processing Record 85 | Norman Wells
# US
# Processing Record 86 | Hibbing
# US
# Processing Record 87 | Palmer
# CA
# Processing Record 88 | Clyde River
# PK
# Processing Record 89 | Keti Bandar
# BF
# Processing Record 90 | Djibo
# MU
# Processing Record 91 | Bambous Virieux
# RU
# Processing Record 92 | Dudinka
# City not found. Skipping...
# City not found. Skipping...
# RE
# Processing Record 93 | Saint-Philippe
# BR
# Processing Record 94 | Cidreira
# MU
# Processing Record 95 | Quatre Cocos
# MV
# Processing Record 96 | Mahibadhoo
# PE
# Processing Record 97 | Pisco
# GL
# Processing Record 98 | Ilulissat
# BR
# Processing Record 99 | Arraial do Cabo
# RU
# Processing Record 100 | Severo-Kuril'sk
# NA
# Processing Record 101 | Oranjemund
# MV
# Processing Record 102 | Hithadhoo
# NC
# Processing Record 103 | Tadine
# CL
# Processing Record 104 | Lebu
# City not found. Skipping...
# GL
# Processing Record 105 | Tasiilaq
# CA
# Processing Record 106 | Bow Island
# EC
# Processing Record 107 | Puerto Ayora
# MX
# Processing Record 108 | Guerrero Negro
# CL
# Processing Record 109 | Coquimbo
# City not found. Skipping...
# SV
# Processing Record 110 | San Miguel
# City not found. Skipping...
# IN
# Processing Record 111 | Kattivakkam
# NG
# Processing Record 112 | Sabla
# MX
# Processing Record 113 | Rosarito
# RU
# Processing Record 114 | Srednekolymsk
# PT
# Processing Record 115 | Cascais
# NP
# Processing Record 116 | Tulsipur
# ZA
# Processing Record 117 | Thabazimbi
# KE
# Processing Record 118 | Garissa
# RU
# Processing Record 119 | Magdagachi
# City not found. Skipping...
# City not found. Skipping...
# RU
# Processing Record 120 | Chokurdakh
# RU
# Processing Record 121 | Teguldet
# ID
# Processing Record 122 | Kupang
# PT
# Processing Record 123 | Lagoa
# RU
# Processing Record 124 | Zaterechnyy
# UY
# Processing Record 125 | Rocha
# IL
# Processing Record 126 | Kiryat Gat
# RU
# Processing Record 127 | Nikolskoye
# ZA
# Processing Record 128 | Saldanha
# IN
# Processing Record 129 | Chima
# AU
# Processing Record 130 | Byron Bay
# HK
# Processing Record 131 | Hong Kong
# NZ
# Processing Record 132 | Mataura
# IT
# Processing Record 133 | Laas
# CN
# Processing Record 134 | Shaowu
# NC
# Processing Record 135 | Poum
# US
# Processing Record 136 | Sitka
# PF
# Processing Record 137 | Atuona
# SE
# Processing Record 138 | Visby
# NG
# Processing Record 139 | Yaan
# PT
# Processing Record 140 | Colares
# JP
# Processing Record 141 | Ishigaki
# SO
# Processing Record 142 | Bandarbeyla
# RU
# Processing Record 143 | Votkinsk
# IN
# Processing Record 144 | Tura
# CA
# Processing Record 145 | Bay Roberts
# NA
# Processing Record 146 | Karasburg
# SL
# Processing Record 147 | Bonthe
# NU
# Processing Record 148 | Alofi
# GL
# Processing Record 149 | Qaanaaq
# ZA
# Processing Record 150 | Plettenberg Bay
# AU
# Processing Record 151 | Port Hedland
# PH
# Processing Record 152 | Ransang
# RU
# Processing Record 153 | Bilibino
# ET
# Processing Record 154 | Gewane
# US
# Processing Record 155 | Hilo
# FR
# Processing Record 156 | Arrondissement d'Ajaccio
# IN
# Processing Record 157 | Port Blair
# AU
# Processing Record 158 | New Norfolk
# US
# Processing Record 159 | Stephenville
# City not found. Skipping...
# US
# Processing Record 160 | Brigantine
# GT
# Processing Record 161 | Champerico
# AU
# Processing Record 162 | Port Macquarie
# RU
# Processing Record 163 | Verkhnyaya Inta
# EG
# Processing Record 164 | Assiut
# AU
# Processing Record 165 | Charters Towers
# RU
# Processing Record 166 | Cherskiy
# GB
# Processing Record 167 | Warrington
# MG
# Processing Record 168 | Beloha
# City not found. Skipping...
# PK
# Processing Record 169 | Baffa
# ID
# Processing Record 170 | Manggar
# CA
# Processing Record 171 | Sept-Iles
# US
# Processing Record 172 | Isla Vista
# US
# Processing Record 173 | Kodiak
# PG
# Processing Record 174 | Kavieng
# ID
# Processing Record 175 | Pemangkat
# GB
# Processing Record 176 | Margate
# City not found. Skipping...
# KZ
# Processing Record 177 | Emba
# ID
# Processing Record 178 | Pamanukan
# ES
# Processing Record 179 | Azuaga
# RU
# Processing Record 180 | Okha
# City not found. Skipping...
# RU
# Processing Record 181 | Ostrovnoy
# LY
# Processing Record 182 | Sabha
# RU
# Processing Record 183 | Yar-Sale
# NO
# Processing Record 184 | Hella
# City not found. Skipping...
# BR
# Processing Record 185 | Placido de Castro
# MR
# Processing Record 186 | Atar
# BR
# Processing Record 187 | Dona Ines
# US
# Processing Record 188 | Batesville
# SJ
# Processing Record 189 | Longyearbyen
# JP
# Processing Record 190 | Nemuro
# IR
# Processing Record 191 | Mahriz
# CL
# Processing Record 192 | Ancud
# City not found. Skipping...
# City not found. Skipping...
# NG
# Processing Record 193 | Kaduna
# City not found. Skipping...
# VE
# Processing Record 194 | Upata
# AU
# Processing Record 195 | Mount Gambier
# ID
# Processing Record 196 | Bengkulu
# EC
# Processing Record 197 | Puerto Baquerizo Moreno
# ES
# Processing Record 198 | Lleida
# ML
# Processing Record 199 | Yorosso
# UY
# Processing Record 200 | Departamento de Maldonado
# MZ
# Processing Record 201 | Manjacaze
# RU
# Processing Record 202 | Provideniya
# BR
# Processing Record 203 | Maragogi
# City not found. Skipping...
# RU
# Processing Record 204 | Belaya Gora
# US
# Processing Record 205 | Shasta Lake
# RU
# Processing Record 206 | Petropavlovka
# US
# Processing Record 207 | Makakilo City
# MX
# Processing Record 208 | Tlacotepec (San Mateo)
# IN
# Processing Record 209 | Amalapuram
# RU
# Processing Record 210 | Irbeyskoye
# City not found. Skipping...
# City not found. Skipping...
# ID
# Processing Record 211 | Sibolga
# City not found. Skipping...
# US
# Processing Record 212 | Portland
# GL
# Processing Record 213 | Qasigiannguit
# ZA
# Processing Record 214 | Richards Bay
# MX
# Processing Record 215 | Todos Santos
# MG
# Processing Record 216 | Sambava
# NC
# Processing Record 217 | Vao
# GL
# Processing Record 218 | Nanortalik
# US
# Processing Record 219 | Kingsport
# RU
# Processing Record 220 | Khatanga
# MU
# Processing Record 221 | Cap Malheureux
# BB
# Processing Record 222 | Bathsheba
# PT
# Processing Record 223 | Ponta Delgada
# ID
# Processing Record 224 | Denpasar
# GL
# Processing Record 225 | Sisimiut
# US
# Processing Record 226 | Cody
# City not found. Skipping...
# US
# Processing Record 227 | Kailua
# AO
# Processing Record 228 | Luanda
# IS
# Processing Record 229 | Olafsvik
# LK
# Processing Record 230 | Matara
# MX
# Processing Record 231 | Ixtapa
# NO
# Processing Record 232 | Sistranda
# RU
# Processing Record 233 | Talnakh
# City not found. Skipping...
# ES
# Processing Record 234 | Cocentaina
# NO
# Processing Record 235 | Honningsvag
# BO
# Processing Record 236 | Puerto Quijarro
# RE
# Processing Record 237 | Sainte-Suzanne
# NZ
# Processing Record 238 | Kaeo
# RU
# Processing Record 239 | Udachny
# RU
# Processing Record 240 | Abrau-Dyurso
# City not found. Skipping...
# RU
# Processing Record 241 | Tiksi
# US
# Processing Record 242 | Brewster
# CL
# Processing Record 243 | Coyhaique
# US
# Processing Record 244 | Hamilton
# City not found. Skipping...
# TG
# Processing Record 245 | Aflao
# NC
# Processing Record 246 | Hienghene
# NO
# Processing Record 247 | Leirvik
# City not found. Skipping...
# City not found. Skipping...
# US
# Processing Record 248 | Ontario
# RU
# Processing Record 249 | Leningradskiy
# TR
# Processing Record 250 | Bafra
# RU
# Processing Record 251 | Pechenga
# RU
# Processing Record 252 | Shumskiy
# US
# Processing Record 253 | Eureka
# City not found. Skipping...
# GR
# Processing Record 254 | Pirgos
# ZA
# Processing Record 255 | East London
# BR
# Processing Record 256 | Aquiraz
# IS
# Processing Record 257 | Vestmannaeyjar
# US
# Processing Record 258 | Nome
# PG
# Processing Record 259 | Vanimo
# City not found. Skipping...
# MX
# Processing Record 260 | Caborca
# NA
# Processing Record 261 | Luderitz
# BW
# Processing Record 262 | Ghanzi
# PF
# Processing Record 263 | Fare
# GM
# Processing Record 264 | Nioro
# JP
# Processing Record 265 | Itoman
# MV
# Processing Record 266 | Kudahuvadhoo
# IN
# Processing Record 267 | Nanpara
# SO
# Processing Record 268 | Jamame
# CN
# Processing Record 269 | Yima
# CA
# Processing Record 270 | Pangnirtung
# VE
# Processing Record 271 | San Cristobal
# US
# Processing Record 272 | Kahului
# City not found. Skipping...
# PT
# Processing Record 273 | Ponta do Sol
# DO
# Processing Record 274 | Pedernales
# KM
# Processing Record 275 | Fomboni
# JP
# Processing Record 276 | Kushima
# CL
# Processing Record 277 | Valparaiso
# TR
# Processing Record 278 | Heraclea
# BR
# Processing Record 279 | Aracati
# JP
# Processing Record 280 | Naze
# AO
# Processing Record 281 | Benguela
# PG
# Processing Record 282 | Kieta
# QA
# Processing Record 283 | Doha
# CA
# Processing Record 284 | Bonavista
# AR
# Processing Record 285 | Santiago del Estero
# AR
# Processing Record 286 | San Juan
# HT
# Processing Record 287 | Jeremie
# OM
# Processing Record 288 | Ibra
# CA
# Processing Record 289 | Iqaluit
# AU
# Processing Record 290 | Ballina
# City not found. Skipping...
# CO
# Processing Record 291 | Aguachica
# NO
# Processing Record 292 | Skjervoy
# KZ
# Processing Record 293 | Ayagoz
# TL
# Processing Record 294 | Airai
# CL
# Processing Record 295 | Constitucion
# CN
# Processing Record 296 | Wenling
# US
# Processing Record 297 | Aiken
# City not found. Skipping...
# BR
# Processing Record 298 | Cruzeiro do Sul
# NZ
# Processing Record 299 | Tuatapere
# GH
# Processing Record 300 | Esim
# SV
# Processing Record 301 | Acajutla
# AU
# Processing Record 302 | Geraldton
# PL
# Processing Record 303 | Kolobrzeg
# TR
# Processing Record 304 | Kadirli
# RU
# Processing Record 305 | Pevek
# US
# Processing Record 306 | Nanakuli
# US
# Processing Record 307 | Twentynine Palms
# CN
# Processing Record 308 | Kashgar
# NO
# Processing Record 309 | Roald
# PK
# Processing Record 310 | Pasni
# RU
# Processing Record 311 | Belyy Yar
# IR
# Processing Record 312 | Darab
# PY
# Processing Record 313 | Capiibary
# MV
# Processing Record 314 | Ugoofaaru
# RU
# Processing Record 315 | Deputatsky
# BR
# Processing Record 316 | Touros
# MR
# Processing Record 317 | Nouadhibou
# RU
# Processing Record 318 | Petrov Val
# RU
# Processing Record 319 | Cherdyn
# US
# Processing Record 320 | College
# RU
# Processing Record 321 | Lavrentiya
# TR
# Processing Record 322 | Sinop
# PH
# Processing Record 323 | Marawi
# BW
# Processing Record 324 | Shakawe
# EC
# Processing Record 325 | Cuenca
# CA
# Processing Record 326 | Marystown
# MR
# Processing Record 327 | Adrar
# US
# Processing Record 328 | Fortuna
# ID
# Processing Record 329 | Tanggul
# MX
# Processing Record 330 | Coahuayana Viejo
# RU
# Processing Record 331 | Bredy
# YE
# Processing Record 332 | Aden
# PE
# Processing Record 333 | Ayabaca
# AR
# Processing Record 334 | Necochea
# CA
# Processing Record 335 | Thompson
# RU
# Processing Record 336 | Andreapol
# BR
# Processing Record 337 | Cururupu
# JP
# Processing Record 338 | Muroto
# KE
# Processing Record 339 | Mandera
# CN
# Processing Record 340 | Erenhot
# GB
# Processing Record 341 | Penzance
# TH
# Processing Record 342 | Yaring
# TZ
# Processing Record 343 | Mlowo
# CN
# Processing Record 344 | Gejiu
# HR
# Processing Record 345 | Trogir
# SO
# Processing Record 346 | Mogadishu
# AR
# Processing Record 347 | Comodoro Rivadavia
# GF
# Processing Record 348 | Apatou
# IN
# Processing Record 349 | Bikaner
# CD
# Processing Record 350 | Kaniama
# IN
# Processing Record 351 | Mangrol
# MO
# Processing Record 352 | Macao
# CA
# Processing Record 353 | Riviere-au-Renard
# BR
# Processing Record 354 | Santa Helena
# RU
# Processing Record 355 | Ulkan
# PT
# Processing Record 356 | Vila Franca do Campo
# MX
# Processing Record 357 | Panaba
# PT
# Processing Record 358 | Ribeira Grande
# US
# Processing Record 359 | Mayo
# IT
# Processing Record 360 | Capaci
# GF
# Processing Record 361 | Sinnamary
# IR
# Processing Record 362 | Dehloran
# US
# Processing Record 363 | Weston
# TZ
# Processing Record 364 | Madimba
# IN
# Processing Record 365 | Tikaitnagar
# IN
# Processing Record 366 | Fatehpur
# PH
# Processing Record 367 | Isabela
# City not found. Skipping...
# AI
# Processing Record 368 | The Valley
# CD
# Processing Record 369 | Lusambo
# PH
# Processing Record 370 | Gigmoto
# PE
# Processing Record 371 | Putina
# AR
# Processing Record 372 | Veinticinco de Mayo
# UA
# Processing Record 373 | Lokhvytsya
# AU
# Processing Record 374 | Kurri Kurri
# US
# Processing Record 375 | Westport
# RU
# Processing Record 376 | Aykhal
# US
# Processing Record 377 | Ukiah
# ES
# Processing Record 378 | Provincia de Las Palmas
# ML
# Processing Record 379 | Araouane
# US
# Processing Record 380 | Avera
# RU
# Processing Record 381 | Batagay-Alyta
# NO
# Processing Record 382 | Vardo
# CD
# Processing Record 383 | Bumba
# SB
# Processing Record 384 | Kirakira
# MX
# Processing Record 385 | Acapulco de Juarez
# RU
# Processing Record 386 | Gunib
# City not found. Skipping...
# RU
# Processing Record 387 | Sharanga
# RU
# Processing Record 388 | Nar'yan-Mar
# CN
# Processing Record 389 | Kumul
# AR
# Processing Record 390 | Bariloche
# IS
# Processing Record 391 | Hofn
# RU
# Processing Record 392 | Vysokogornyy
# BR
# Processing Record 393 | Carutapera
# IN
# Processing Record 394 | Kaman
# ES
# Processing Record 395 | Muros
# City not found. Skipping...
# TZ
# Processing Record 396 | Mafinga
# US
# Processing Record 397 | Half Moon Bay
# FO
# Processing Record 398 | Vestmanna
# IR
# Processing Record 399 | Borazjan
# PG
# Processing Record 400 | Samarai
# NO
# Processing Record 401 | Sorland
# CN
# Processing Record 402 | Shenjiamen
# AU
# Processing Record 403 | Alice Springs
# RU
# Processing Record 404 | Verkhoyansk
# IE
# Processing Record 405 | Skibbereen
# RU
# Processing Record 406 | Pitkyaranta
# GL
# Processing Record 407 | Nuuk
# IN
# Processing Record 408 | Satana
# City not found. Skipping...
# PE
# Processing Record 409 | Huarmey
# CO
# Processing Record 410 | Inirida
# UG
# Processing Record 411 | Kaabong
# MX
# Processing Record 412 | Cosala
# PE
# Processing Record 413 | Acari
# PE
# Processing Record 414 | Chachapoyas
# MX
# Processing Record 415 | Isla Mujeres
# MZ
# Processing Record 416 | Inhambane
# CA
# Processing Record 417 | Kapuskasing
# US
# Processing Record 418 | Laramie
# ES
# Processing Record 419 | Bereda
# ET
# Processing Record 420 | Jijiga
# RU
# Processing Record 421 | Nizhniy Tsasuchey
# CN
# Processing Record 422 | Yong'an
# US
# Processing Record 423 | Laguna
# CN
# Processing Record 424 | Xichang
# CN
# Processing Record 425 | Yinchuan
# ID
# Processing Record 426 | Bandar
# RU
# Processing Record 427 | Usogorsk
# FI
# Processing Record 428 | Lieksa
# GQ
# Processing Record 429 | Bata
# SA
# Processing Record 430 | Sakakah
# OM
# Processing Record 431 | Salalah
# City not found. Skipping...
# JP
# Processing Record 432 | Hasaki
# AU
# Processing Record 433 | Kununurra
# AR
# Processing Record 434 | Rosario
# US
# Processing Record 435 | Marquette
# BR
# Processing Record 436 | Coromandel
# RU
# Processing Record 437 | Bogorodskoye
# BR
# Processing Record 438 | Alta Floresta
# CA
# Processing Record 439 | Saint-Augustin
# KZ
# Processing Record 440 | Semey
# ZM
# Processing Record 441 | Mwinilunga
# RO
# Processing Record 442 | Asau
# BR
# Processing Record 443 | Santa Maria da Vitoria
# PT
# Processing Record 444 | Praia da Vitoria
# CD
# Processing Record 445 | Kamina
# ID
# Processing Record 446 | Sabang
# ES
# Processing Record 447 | Zafra
# JM
# Processing Record 448 | Morant Bay
# ID
# Processing Record 449 | Labuhan
# NO
# Processing Record 450 | Andenes
# KI
# Processing Record 451 | Bairiki Village
# MW
# Processing Record 452 | Chikwawa
# US
# Processing Record 453 | Saint George
# GB
# Processing Record 454 | Thurso
# SE
# Processing Record 455 | Umea
# IT
# Processing Record 456 | Provincia di Brindisi
# US
# Processing Record 457 | Ketchikan
# ID
# Processing Record 458 | Padang
# CA
# Processing Record 459 | Aklavik
# NG
# Processing Record 460 | Bara
# CU
# Processing Record 461 | Jaguey Grande
# PF
# Processing Record 462 | Tautira
# City not found. Skipping...
# MU
# Processing Record 463 | Mahebourg
# City not found. Skipping...
# US
# Processing Record 464 | Broome
# US
# Processing Record 465 | Douglas
# CO
# Processing Record 466 | Tasco
# JP
# Processing Record 467 | Katsuura
# IS
# Processing Record 468 | Hvolsvollur
# GW
# Processing Record 469 | Bubaque
# AR
# Processing Record 470 | Rawson
# BR
# Processing Record 471 | Pauini
# RU
# Processing Record 472 | Krasnosel'kup
# NL
# Processing Record 473 | Dalen
# CA
# Processing Record 474 | Kamsack
# RE
# Processing Record 475 | Saint-Joseph
# BR
# Processing Record 476 | Guaratinga
# US
# Processing Record 477 | Homer
# City not found. Skipping...
# BY
# Processing Record 478 | Bolshevik
# AU
# Processing Record 479 | Lakes Entrance
# MX
# Processing Record 480 | Mulege
# ZW
# Processing Record 481 | Hwange
# BQ
# Processing Record 482 | Kralendijk
# PT
# Processing Record 483 | Camacha
# ZW
# Processing Record 484 | Zvishavane
# City not found. Skipping...
# US
# Processing Record 485 | Fallon
# BR
# Processing Record 486 | Conchal
# CA
# Processing Record 487 | Medicine Hat
# RU
# Processing Record 488 | Kungurtug
# PH
# Processing Record 489 | Kalawit
# FO
# Processing Record 490 | Klaksvik
# NO
# Processing Record 491 | Berlevag
# LK
# Processing Record 492 | Hambantota
# ID
# Processing Record 493 | Manokwari
# IR
# Processing Record 494 | Ravar
# MM
# Processing Record 495 | Falam
# SA
# Processing Record 496 | Umm Lajj
# NO
# Processing Record 497 | Avanuorri
# US
# Processing Record 498 | Virginia Beach
# AU
# Processing Record 499 | Port Augusta
# GN
# Processing Record 500 | Dalaba
# ID
# Processing Record 501 | Banda Aceh
# ES
# Processing Record 502 | Vic
# RU
# Processing Record 503 | Kuytun
# NI
# Processing Record 504 | Laguna de Perlas
# RU
# Processing Record 505 | Chumikan
# City not found. Skipping...
# RU
# Processing Record 506 | Aktash
# RU
# Processing Record 507 | Batetskiy
# JP
# Processing Record 508 | Shingu
# IT
# Processing Record 509 | Nola
# NO
# Processing Record 510 | Mehamn
# CN
# Processing Record 511 | Zhangjiakou Shi Xuanhua Qu
# PG
# Processing Record 512 | Ialibu
# SE
# Processing Record 513 | Oxeloesund
# RU
# Processing Record 514 | Vagay
# BR
# Processing Record 515 | Vilhena
# ID
# Processing Record 516 | Atambua
# VN
# Processing Record 517 | Ninh Binh
# SO
# Processing Record 518 | Berbera
# RU
# Processing Record 519 | Khasan
# US
# Processing Record 520 | Norfolk
# FR
# Processing Record 521 | Rouvroy
# CN
# Processing Record 522 | Jiazi
# ID
# Processing Record 523 | Barabai
# MX
# Processing Record 524 | San Quintin
# VU
# Processing Record 525 | Sola
# CO
# Processing Record 526 | Mutis
# PF
# Processing Record 527 | Faanui
# City not found. Skipping...
# CI
# Processing Record 528 | Soubre
# BR
# Processing Record 529 | Maceio
# GB
# Processing Record 530 | Lerwick
# PE
# Processing Record 531 | Mancora
# RU
# Processing Record 532 | Chara
# BR
# Processing Record 533 | Carauari
# CA
# Processing Record 534 | Moncton
# RU
# Processing Record 535 | Yashkul
# MG
# Processing Record 536 | Antalaha
# TH
# Processing Record 537 | Yala
# ZM
# Processing Record 538 | Kalengwa
# SN
# Processing Record 539 | Oussouye
# City not found. Skipping...
# NC
# Processing Record 540 | Koumac
# ID
# Processing Record 541 | Meulaboh
# ZW
# Processing Record 542 | Norton
# AR
# Processing Record 543 | San Rafael
# LR
# Processing Record 544 | Monrovia
# IT
# Processing Record 545 | Bruneck
# LR
# Processing Record 546 | Harper
# PH
# Processing Record 547 | Buluang
# MM
# Processing Record 548 | Mogok
# IT
# Processing Record 549 | Crotone
# JP
# Processing Record 550 | Wajima
# IS
# Processing Record 551 | Grindavik
# BR
# Processing Record 552 | Coari
# Complete
# size of list
# 552

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df=pd.DataFrame(lst)
df.info
# Out:
# <bound method DataFrame.info of        lat   temp     city_name  cloudiness  wind_speed  humidity        date  \
# 0   -21.20  84.20         Vaini          75        9.17        79  1578803901
# 1    32.21  63.25       Liliani         100        6.55        19  1578803901
# 2   -54.80  48.20       Ushuaia          75        4.12        87  1578803901
# 3    14.90  67.69    Sao Filipe          25       22.15        69  1578803901
# 4    18.18  80.60  Port Antonio          20       29.97        78  1578803901
# ..     ...    ...           ...         ...         ...       ...         ...
# 547  22.92  72.03         Mogok           0        2.57        40  1578803934
# 548  39.09  48.20       Crotone         100        9.64        84  1578803934
# 549  37.40  42.80        Wajima          75        9.17        81  1578803934
# 550  63.84  25.65     Grindavik          75       12.75        79  1578803934
# 551  -4.08  74.01         Coari          79        1.19        90  1578803935
#
#     country
# 0        TO
# 1        PK
# 2        AR
# 3        CV
# 4        JM
# ..      ...
# 547      MM
# 548      IT
# 549      JP
# 550      IS
# 551      BR
#
# [552 rows x 8 columns]>

# %%
df=pd.DataFrame(lst)
df.head()
df.to_csv("/Users/akashchhabra/Desktop/bootcamp/weatherData.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
df.plot(kind='scatter',x="lat",y="temp")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
df.plot(kind='scatter',x="lat",y="humidity")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
df.plot(kind='scatter',x="lat",y="cloudiness")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
df.plot(kind='scatter',x="lat",y="wind_speed")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
north=df.where(df["lat"]>=0).dropna()
south=df.where(df["lat"]>=0).dropna()
# Out:
#       lat   temp             city_name  cloudiness  wind_speed  humidity  \
# 1   32.21  63.25               Liliani       100.0        6.55      19.0
# 3   14.90  67.69            Sao Filipe        25.0       22.15      69.0
# 4   18.18  80.60          Port Antonio        20.0       29.97      78.0
# 7   55.23  42.75              Naestved       100.0       17.22     100.0
# 10  50.08  -2.07                 Tyrma       100.0        2.59      89.0
# 13  31.67  33.80                Turaif        90.0        4.70     100.0
# 14   4.77  76.62               Kapoeta        14.0        6.76      14.0
# 15  19.22  78.96          San Patricio         8.0        5.30      61.0
# 17  73.51  -5.24                Dikson       100.0       12.57      94.0
# 20  71.92   6.62             Saskylakh        93.0        7.65      91.0
# 21  29.27  47.71                 Jumla         0.0        2.98      49.0
# 22  61.95  -5.60                Evensk       100.0        7.11      96.0
# 23  72.79  -9.53             Upernavik        93.0        4.72      60.0
# 25  12.68  75.65            Larreynaga         0.0        5.73      73.0
# 26  42.60  61.43                Albany        90.0       16.11      68.0
# 29  41.37  58.01                Bethel        90.0       12.75      93.0
# 32  66.04  19.40               Husavik        56.0       16.11      73.0
# 33  64.56  30.20          Severodvinsk        90.0        8.95      92.0
# 34  16.08  75.20  San Pedro Buenavista         5.0       19.46      69.0
# 35   5.35  80.64                 Hobyo        98.0       14.45      73.0
# 36  71.29 -18.40                Barrow         1.0       21.92      68.0
# 37  34.64  49.78                Lompoc         1.0       10.29      62.0
# 40  50.70  35.60            Port Hardy        90.0        9.17     100.0
# 42  49.17  36.18            Chilliwack        90.0        2.82      96.0
# 46  69.45 -18.40           Tuktoyaktuk        90.0        9.17      75.0
#
#             date country
# 1   1.578804e+09      PK
# 3   1.578804e+09      CV
# 4   1.578804e+09      JM
# 7   1.578804e+09      DK
# 10  1.578804e+09      RU
# 13  1.578804e+09      SA
# 14  1.578804e+09      SS
# 15  1.578804e+09      MX
# 17  1.578804e+09      RU
# 20  1.578804e+09      RU
# 21  1.578804e+09      NP
# 22  1.578804e+09      RU
# 23  1.578804e+09      GL
# 25  1.578804e+09      NI
# 26  1.578804e+09      US
# 29  1.578804e+09      US
# 32  1.578804e+09      IS
# 33  1.578804e+09      RU
# 34  1.578804e+09      MX
# 35  1.578804e+09      SO
# 36  1.578804e+09      US
# 37  1.578804e+09      US
# 40  1.578804e+09      CA
# 42  1.578804e+09      CA
# 46  1.578804e+09      CA

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope,intercept,r_value,_,_)=linregress(north['lat'],north['temp'])
print(f'The r_value is {r_value}')
fit=slope*north['lat']+intercept
fig, ax= plt.subplots()
ax.plot(north['lat'],fit,c='r')
ax.scatter(north['lat'],north['temp'])
plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
plt.show()
# Out:
# The r_value is -0.8619652435865576

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope,intercept,r_value,_,_)=linregress(south['lat'],south['temp'])
print(f'The r_value is {r_value}')
fit=slope*south['lat']+intercept
fig, ax= plt.subplots()
ax.plot(south['lat'],fit,c='r')
ax.scatter(north['lat'],north['temp'])
plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
plt.show()
# Out:
# The r_value is -0.8619652435865576

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope,intercept,r_value,_,_)=linregress(north['lat'],north['humidity'])
print(f'The r_value is {r_value}')
fit=slope*north['lat']+intercept
fig, ax= plt.subplots()
ax.plot(north['lat'],fit,c='r')
ax.scatter(north['lat'],north['humidity'])
plt.xlabel('Latitude')
plt.ylabel('humidity')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
plt.show()
# Out:
# The r_value is 0.2928937256002021

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope,intercept,r_value,_,_)=linregress(south['lat'],south['humidity'])
print(f'The r_value is {r_value}')
fit=slope*south['lat']+intercept
fig, ax= plt.subplots()
ax.plot(south['lat'],fit,c='r')
ax.scatter(north['lat'],north['humidity'])
plt.xlabel('Latitude')
plt.ylabel('humidity')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
plt.show()
# Out:
# The r_value is 0.2928937256002021

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope,intercept,r_value,_,_)=linregress(north['lat'],north['cloudiness'])
print(f'The r_value is {r_value}')
fit=slope*north['lat']+intercept
fig, ax= plt.subplots()
ax.plot(north['lat'],fit,c='r')
ax.scatter(north['lat'],north['cloudiness'])
plt.xlabel('Latitude')
plt.ylabel('cloudiness')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
plt.show()
# Out:
# The r_value is 0.34256727934079384

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope,intercept,r_value,_,_)=linregress(south['lat'],south['cloudiness'])
print(f'The r_value is {r_value}')
fit=slope*south['lat']+intercept
fig, ax= plt.subplots()
ax.plot(south['lat'],fit,c='r')
ax.scatter(north['lat'],north['cloudiness'])
plt.xlabel('Latitude')
plt.ylabel('cloudiness')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
plt.show()
# Out:
# The r_value is 0.34256727934079384

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(slope,intercept,r_value,_,_)=linregress(north['lat'],north['wind_speed'])
print(f'The r_value is {r_value}')
fit=slope*north['lat']+intercept
fig, ax= plt.subplots()
ax.plot(north['lat'],fit,c='r')
ax.scatter(north['lat'],north['wind_speed'])
plt.xlabel('Latitude')
plt.ylabel('wind_speed')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
plt.show()
# Out:
# The r_value is 0.11504142262794892

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(slope,intercept,r_value,_,_)=linregress(south['lat'],south['wind_speed'])
print(f'The r_value is {r_value}')
fit=slope*south['lat']+intercept
fig, ax= plt.subplots()
ax.plot(south['lat'],fit,c='r')
ax.scatter(north['lat'],north['wind_speed'])
plt.xlabel('Latitude')
plt.ylabel('wind_speed')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
plt.show()
# Out:
# The r_value is 0.11504142262794892
